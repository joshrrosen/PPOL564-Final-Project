# %%
#!pip install opencv-python

# %%
#import libraries
import cv2
from matplotlib import pyplot as plt

# %%
# create figure
fig = plt.figure(figsize=(20, 15))
  
# setting values to rows and column variables
rows = 2
columns = 2
  
# reading images
Image1 = cv2.imread('D:/Pictures/speedlim.PNG')
Image2 = cv2.imread('D:/Pictures/routetype.PNG')
Image3 = cv2.imread('D:/Pictures/lanes.PNG')
Image4 = cv2.imread('D:/Pictures/premove.PNG')
  
# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)
  
# showing image
plt.imshow(Image1)
plt.axis('off')
  
# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)
  
# showing image
plt.imshow(Image2)
plt.axis('off')
  
# Adds a subplot at the 3rd position
fig.add_subplot(rows, columns, 3)
  
# showing image
plt.imshow(Image3)
plt.axis('off')
  
# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 4)
  
 #showing image
plt.imshow(Image4)
plt.axis('off')
plt.savefig('fig', dpi=300, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(20, 15))
  
# setting values to rows and column variables
columns = 2
  
# reading images
Image1 = cv2.imread('D:/Pictures/disabledamage.PNG')
Image2 = cv2.imread('D:/Pictures/location.PNG')
  
# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)
  
# showing image
plt.imshow(Image1)
plt.axis('off')
  
# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)
  
# showing image
plt.imshow(Image2)
plt.axis('off')
plt.savefig('fig', dpi=300, bbox_inches='tight')
